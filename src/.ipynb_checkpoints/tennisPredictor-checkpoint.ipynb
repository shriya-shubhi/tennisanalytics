# %% [markdown]
# ### This is a program to identify a winner / loser in a tournament in Women's Tennis for all Grand Slams

# %% [markdown]
# #### Import all the libraries

# %%
import pandas as pd
import logging
import sys
from importlib import reload
import matplotlib as plt
import datetime

# %%
logger = logging.getLogger()

logging.basicConfig(format=' %(levelname)s : %(message)s',
                     level=logging.INFO, stream=sys.stdout)
reload(logging)
# Out:
# <module 'logging' from '//anaconda3/lib/python3.7/logging/__init__.py'>

# %%
cols_of_interest = [ 'year', 'best_of', 'loser_age', 'winner_age', 
                    'draw_size', 'loser_id','loser_ioc', 'loser_name',
                    'loser_rank', 'winner_id', 'winner_name',
                    'winner_ioc','winner_rank','tourney_id', 
                    'tourney_name','tourney_date', 'score']

# %% [markdown]
# #### Read data from WTA ( Women's tennis) for last 20 years

# %%
#Matches
matches = pd.read_csv("../wta/matches.csv", low_memory=False)

# %%
#Get all the players
players = pd.read_csv("../wta/players.csv", sep=',', encoding='latin-1')
players.head(n=10)
# Out:
#    player_id  first_name       last_name hand  birth_date country_code
# 0     200001     Martina          Hingis    R  19800930.0          SUI
# 1     200002     Mirjana           Lucic    R  19820309.0          CRO
# 2     200003     Justine           Henin    R  19820601.0          BEL
# 3     200004  Kerry Anne            Guse    R  19721204.0          AUS
# 4     200005      Jolene  Watanabe Giltz    R  19680831.0          USA
# 5     200006      Karina       Habsudova    R  19730802.0          SVK
# 6     200007     Silvija          Talaja    R  19780114.0          CRO
# 7     200008      Alicia           Molik    R  19810127.0          AUS
# 8     200009    Tamarine      Tanasugarn    R  19770524.0          THA
# 9     200010        Rita          Grande    R  19750323.0          ITA

# %%
#Get all the qualifying matches
qualifying_matches = pd.read_csv("../wta/qualifying_matches.csv", low_memory=False)

# %%
#Get all the Rankings
rankings = pd.read_csv("../wta/rankings.csv")

# %% [markdown]
# #### Enrich the matches data

# %%
#convert the player ID to an integer
matches['loser_id'] = matches['loser_id'].apply( lambda x: int(x))
matches['winner_id'] = matches['winner_id'].apply( lambda x: int(x))

#here, we are changing all of the N/A loser and winner ages to 0
matches['loser_age'] = matches['loser_age'].fillna(0)
matches['winner_age'] = matches['winner_age'].fillna(0)

#here, we are converting the loser and winner ages to integers
matches['loser_age'] = matches['loser_age'].apply( lambda x: int(x))
matches['winner_age'] = matches['winner_age'].apply( lambda x: int(x))
matches['year'] = matches['tourney_date'].apply( lambda x: str(x)[:4])

# %% [markdown]
# # Features

# %% [markdown]
# 1. number of matches the player has won against the other mention
#
# 2. number of matches the player has LOST against the other player
#
# 3. The number of matches the player has won in the past year from the date of the search
#
# 4. The surface of the court
#     - Can figure out which surface the player is best at by finding the number of matches
#     the player has won on each surface in the past year from the date of the search
# 5. The age of the player - (older players are prone to have deteriorating play level, health, and stamina, which means
#     they are more likely to lose)

# %%
def findNextWinner ( matches, player1, player2  ):
    player1_wins =  matches [( matches['winner_name'] == player1) & ( matches['loser_name'] == player2 )] 
    
    curr_year = datetime.datetime.today()
    prev_year = datetime.datetime.today() - datetime.timedelta(days= 365)
    
    player1_win_last_year =  player1_wins [player1_wins['year'] == prev_year] 
    player2_wins =  matches [( matches['winner_name'] == player2) & ( matches['loser_name'] == player1 )] 
    player2_wins_last_year = player2_wins [player2_wins['year']==  prev_year ] 

    player1_win_count = len(matches [( matches['winner_name'] == player1) & ( matches['loser_name'] == player2 )])
    player1_win_last_year_count =   len( player1_wins [player1_wins['year'] == prev_year ] )
    
    player2_win_count = len(matches [( matches['winner_name'] == player2) & ( matches['loser_name'] == player1 )])
    player2_win_last_year_count =  len(player2_wins [player2_wins['year']== prev_year])

    logger.info(" %s has won %s matches || %s has won %s matches" % ( player1, player1_win_count, player2, player2_win_count) ) 
    
    if (player1_win_count == 0 & player2_win_count == 0):
        msg = "Sorry, %s has not played with %s. So, we don't have enough information to predict winner" % (player1, player2) 
        return player1, 0
    
    player1chance = int( 100* (player1_win_count)/(player1_win_count + player2_win_count))
    
    scores = matches [( matches['winner_name'] == player1) & ( matches['loser_name'] == player2 )]['score']
#     logger.info("%s against %s: Scores: \n %s" %( player1, player2, scores ))
    
    logger.info(" In last year, %s has won %s matches || %s has won %s matches" % ( player1, player1_win_last_year_count, player2, player2_win_last_year_count) ) 

    last_year_wins = player1_win_last_year_count + player2_win_last_year_count
    
    if ( last_year_wins !=0 ):
        player1chanceyear = int( ( (100 * player1_win_last_year_count) / (last_year_wins )) ) 
    else:
        player1chanceyear = 0
        logger.info("Sorry, the two players haven't played in past one year.")
        
        if player1chanceyear == 0:
            player1totalchance = player1chance
            
        else:
            player1totalchance = (0.6 * player1chance) + (0.4 * player1chanceyear)
    
    logger.info("Based on this information, %s has a %s percent chance of winning the next match" % (player1, player1totalchance))
    return player1, player1totalchance

# %%
def applyScoreWeights():
    logger.info("apply score weights")

# %% [raw]
# 1. find all of the matches that both have ever played(won and lost)
# 2. so, there will be two arrays: one for each player
# 3. run a for loop that will break when winner1 == winner2 or winner1 == loser 2 or loser1 == winner2 or loser2 == loser1
# 4. if any of the above conditions is correct: set a variable common equal to that name
# 5. then, find all of the matches that common has played against each of the aforementioned players
# 6. find the probability each player has of winning against common
# 7. find the greater probability and that's the winner!

# %%
def playerOpps(matches, player):
    
    player_win_matches =   matches[ ( matches['winner_name'] == player ) ]
    player_lost_matches =  matches[(matches['loser_name'] == player) ]
    l = player_win_matches[['loser_name']]
    w = player_lost_matches[['winner_name']]
    
    player_opps = list(l.loser_name.unique()) + list(w.winner_name.unique() )
    logger.info("%s has played a total of %d other players" %( player, len(player_opps)))
    return player_opps

# %%
def commonPlayer(list1, list2):
    list3 = [value for value in list1 if value in list2] 
    logger.info(" There are %s common players." %( len(list3)))
    return list3

# %%
player1 = "Serena Williams"
player2 = "Venus Williams"

# %%
player1_chance = findNextWinner(matches, player1, player2)
logger.info("player1_chance >.")
if (player1_chance[1] == 0 ):
#     lets a common player
    player1_opps = playerOpps(matches, player1)
    player2_opps = playerOpps(matches, player2)
    common_players = commonPlayer(player1_opps, player2_opps)
    for common_player in common_players:
        logger.info("****************************************\n")
        logger.info("Common Player is: %s" % ( common_player))
        player = findNextWinner(matches, player1, common_player)
        data = findNextWinner(matches, player2, common_player)
else:
# Out:
#  INFO :  Serena Williams has won 17 matches || Venus Williams has won 8 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Venus Williams has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 68 percent chance of winning the next match
# ('Serena Williams', 68)

# %%
player1_opps = playerOpps(matches, player1)
player2_opps = playerOpps(matches, player2)
logger.info("Player 1  opponents: %s" % ( len(player1_opps)) ) 
common_players = commonPlayer(player1_opps, player2_opps)
# Out:
#  INFO : Simona Halep has played a total of 222 other players
#  INFO : Martina Hingis has played a total of 166 other players
#  INFO : Player 1  opponents: 222
#  INFO :  There are 54 common players.
# ['Olga Savchuk',
#  'Patty Schnyder',
#  'Iveta Benesova',
#  'Nuria Llagostera Vives',
#  'Urszula Radwanska',
#  'Alla Kudryavtseva',
#  'Greta Arn',
#  'Svetlana Kuznetsova',
#  'Na Li',
#  'Daniela Hantuchova']

# %%
player2 = "Martina Hingis"
player1 = "Serena Williams"
for common_player in common_players:
    logger.info("****************************************\n")
    logger.info("Common Player is: %s" % ( common_player))
    player = findNextWinner(matches, player1, common_player)
    data = findNextWinner(matches, player2, common_player)
# Out:
#  INFO : ****************************************
#
#  INFO : Common Player is: Olga Savchuk
#  INFO :  Serena Williams has won 0 matches || Olga Savchuk has won 0 matches
#  INFO :  Martina Hingis has won 1 matches || Olga Savchuk has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Olga Savchuk has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Patty Schnyder
#  INFO :  Serena Williams has won 6 matches || Patty Schnyder has won 4 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Patty Schnyder has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 60 percent chance of winning the next match
#  INFO :  Martina Hingis has won 0 matches || Patty Schnyder has won 2 matches
#  INFO : ****************************************
#
#  INFO : Common Player is: Iveta Benesova
#  INFO :  Serena Williams has won 3 matches || Iveta Benesova has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Iveta Benesova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Iveta Benesova has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Iveta Benesova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Nuria Llagostera Vives
#  INFO :  Serena Williams has won 0 matches || Nuria Llagostera Vives has won 0 matches
#  INFO :  Martina Hingis has won 1 matches || Nuria Llagostera Vives has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Nuria Llagostera Vives has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Urszula Radwanska
#  INFO :  Serena Williams has won 5 matches || Urszula Radwanska has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Urszula Radwanska has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 0 matches || Urszula Radwanska has won 1 matches
#  INFO : ****************************************
#
#  INFO : Common Player is: Alla Kudryavtseva
#  INFO :  Serena Williams has won 0 matches || Alla Kudryavtseva has won 0 matches
#  INFO :  Martina Hingis has won 1 matches || Alla Kudryavtseva has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Alla Kudryavtseva has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Greta Arn
#  INFO :  Serena Williams has won 1 matches || Greta Arn has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Greta Arn has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Greta Arn has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Greta Arn has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Svetlana Kuznetsova
#  INFO :  Serena Williams has won 10 matches || Svetlana Kuznetsova has won 3 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Svetlana Kuznetsova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 76 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Svetlana Kuznetsova has won 2 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Svetlana Kuznetsova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 50 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Na Li
#  INFO :  Serena Williams has won 11 matches || Na Li has won 2 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Na Li has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 84 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Na Li has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Na Li has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Daniela Hantuchova
#  INFO :  Serena Williams has won 9 matches || Daniela Hantuchova has won 2 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Daniela Hantuchova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 81 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Daniela Hantuchova has won 3 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Daniela Hantuchova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 40 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Nadia Petrova
#  INFO :  Serena Williams has won 7 matches || Nadia Petrova has won 3 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Nadia Petrova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 70 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Nadia Petrova has won 1 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Nadia Petrova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 66 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Anabel Medina Garrigues
#  INFO :  Serena Williams has won 2 matches || Anabel Medina Garrigues has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Anabel Medina Garrigues has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Anabel Medina Garrigues has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Anabel Medina Garrigues has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Jelena Jankovic
#  INFO :  Serena Williams has won 10 matches || Jelena Jankovic has won 4 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Jelena Jankovic has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 71 percent chance of winning the next match
#  INFO :  Martina Hingis has won 0 matches || Jelena Jankovic has won 2 matches
#  INFO : ****************************************
#
#  INFO : Common Player is: Klara Koukalova
#  INFO :  Serena Williams has won 4 matches || Klara Koukalova has won 2 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Klara Koukalova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 66 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Klara Koukalova has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Klara Koukalova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Agnieszka Radwanska
#  INFO :  Serena Williams has won 10 matches || Agnieszka Radwanska has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Agnieszka Radwanska has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 0 matches || Agnieszka Radwanska has won 2 matches
#  INFO : ****************************************
#
#  INFO : Common Player is: Yvonne Meusburger
#  INFO :  Serena Williams has won 0 matches || Yvonne Meusburger has won 0 matches
#  INFO :  Martina Hingis has won 1 matches || Yvonne Meusburger has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Yvonne Meusburger has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Samantha Stosur
#  INFO :  Serena Williams has won 8 matches || Samantha Stosur has won 5 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Samantha Stosur has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 61 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Samantha Stosur has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Samantha Stosur has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Caroline Wozniacki
#  INFO :  Serena Williams has won 10 matches || Caroline Wozniacki has won 1 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Caroline Wozniacki has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 90 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Caroline Wozniacki has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Caroline Wozniacki has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Maria Kirilenko
#  INFO :  Serena Williams has won 8 matches || Maria Kirilenko has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Maria Kirilenko has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 3 matches || Maria Kirilenko has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Maria Kirilenko has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Ana Ivanovic
#  INFO :  Serena Williams has won 9 matches || Ana Ivanovic has won 1 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Ana Ivanovic has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 90 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Ana Ivanovic has won 1 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Ana Ivanovic has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 50 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Sara Errani
#  INFO :  Serena Williams has won 9 matches || Sara Errani has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Sara Errani has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Sara Errani has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Sara Errani has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Serena Williams
#  INFO :  Serena Williams has won 0 matches || Serena Williams has won 0 matches
#  INFO :  Martina Hingis has won 3 matches || Serena Williams has won 4 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Serena Williams has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 42 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Nicole Vaidisova
#  INFO :  Serena Williams has won 4 matches || Nicole Vaidisova has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Nicole Vaidisova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Nicole Vaidisova has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Nicole Vaidisova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Flavia Pennetta
#  INFO :  Serena Williams has won 7 matches || Flavia Pennetta has won 1 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Flavia Pennetta has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 87 percent chance of winning the next match
#  INFO :  Martina Hingis has won 3 matches || Flavia Pennetta has won 1 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Flavia Pennetta has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 75 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Venus Williams
#  INFO :  Serena Williams has won 17 matches || Venus Williams has won 8 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Venus Williams has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 68 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Venus Williams has won 5 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Venus Williams has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 28 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Kateryna Bondarenko
#  INFO :  Serena Williams has won 3 matches || Kateryna Bondarenko has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Kateryna Bondarenko has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Kateryna Bondarenko has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Kateryna Bondarenko has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Victoria Azarenka
#  INFO :  Serena Williams has won 18 matches || Victoria Azarenka has won 4 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Victoria Azarenka has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 81 percent chance of winning the next match
#  INFO :  Martina Hingis has won 0 matches || Victoria Azarenka has won 1 matches
#  INFO : ****************************************
#
#  INFO : Common Player is: Francesca Schiavone
#  INFO :  Serena Williams has won 7 matches || Francesca Schiavone has won 2 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Francesca Schiavone has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 77 percent chance of winning the next match
#  INFO :  Martina Hingis has won 3 matches || Francesca Schiavone has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Francesca Schiavone has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Shuai Peng
#  INFO :  Serena Williams has won 3 matches || Shuai Peng has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Shuai Peng has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Shuai Peng has won 1 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Shuai Peng has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 50 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Flavia Pennetta
#  INFO :  Serena Williams has won 7 matches || Flavia Pennetta has won 1 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Flavia Pennetta has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 87 percent chance of winning the next match
#  INFO :  Martina Hingis has won 3 matches || Flavia Pennetta has won 1 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Flavia Pennetta has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 75 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Samantha Stosur
#  INFO :  Serena Williams has won 8 matches || Samantha Stosur has won 5 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Samantha Stosur has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 61 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Samantha Stosur has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Samantha Stosur has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Jelena Jankovic
#  INFO :  Serena Williams has won 10 matches || Jelena Jankovic has won 4 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Jelena Jankovic has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 71 percent chance of winning the next match
#  INFO :  Martina Hingis has won 0 matches || Jelena Jankovic has won 2 matches
#  INFO : ****************************************
#
#  INFO : Common Player is: Tamarine Tanasugarn
#  INFO :  Serena Williams has won 5 matches || Tamarine Tanasugarn has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Tamarine Tanasugarn has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 3 matches || Tamarine Tanasugarn has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Tamarine Tanasugarn has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Dinara Safina
#  INFO :  Serena Williams has won 6 matches || Dinara Safina has won 2 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Dinara Safina has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 75 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Dinara Safina has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Dinara Safina has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Iveta Benesova
#  INFO :  Serena Williams has won 3 matches || Iveta Benesova has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Iveta Benesova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Iveta Benesova has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Iveta Benesova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Agnieszka Radwanska
#  INFO :  Serena Williams has won 10 matches || Agnieszka Radwanska has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Agnieszka Radwanska has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 0 matches || Agnieszka Radwanska has won 2 matches
#  INFO : ****************************************
#  INFO : Common Player is: Mathilde Johansson
#  INFO :  Serena Williams has won 1 matches || Mathilde Johansson has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Mathilde Johansson has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Mathilde Johansson has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Mathilde Johansson has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Svetlana Kuznetsova
#  INFO :  Serena Williams has won 10 matches || Svetlana Kuznetsova has won 3 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Svetlana Kuznetsova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 76 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Svetlana Kuznetsova has won 2 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Svetlana Kuznetsova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 50 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Anabel Medina Garrigues
#  INFO :  Serena Williams has won 2 matches || Anabel Medina Garrigues has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Anabel Medina Garrigues has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Anabel Medina Garrigues has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Anabel Medina Garrigues has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Jelena Dokic
#  INFO :  Serena Williams has won 4 matches || Jelena Dokic has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Jelena Dokic has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Jelena Dokic has won 1 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Jelena Dokic has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 66 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Serena Williams
#  INFO :  Serena Williams has won 0 matches || Serena Williams has won 0 matches
#  INFO :  Martina Hingis has won 3 matches || Serena Williams has won 4 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Serena Williams has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 42 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Sybille Bammer
#  INFO :  Serena Williams has won 0 matches || Sybille Bammer has won 2 matches
#  INFO :  Martina Hingis has won 1 matches || Sybille Bammer has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Sybille Bammer has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Kim Clijsters
#  INFO :  Serena Williams has won 6 matches || Kim Clijsters has won 2 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Kim Clijsters has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 75 percent chance of winning the next match
#  INFO :  Martina Hingis has won 4 matches || Kim Clijsters has won 5 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Kim Clijsters has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 44 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Victoria Azarenka
#  INFO :  Serena Williams has won 18 matches || Victoria Azarenka has won 4 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Victoria Azarenka has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 81 percent chance of winning the next match
#  INFO :  Martina Hingis has won 0 matches || Victoria Azarenka has won 1 matches
#  INFO : ****************************************
#
#  INFO : Common Player is: Caroline Wozniacki
#  INFO :  Serena Williams has won 10 matches || Caroline Wozniacki has won 1 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Caroline Wozniacki has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 90 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Caroline Wozniacki has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Caroline Wozniacki has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Maria Sharapova
#  INFO :  Serena Williams has won 19 matches || Maria Sharapova has won 2 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Maria Sharapova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 90 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Maria Sharapova has won 2 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Maria Sharapova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 33 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Venus Williams
#  INFO :  Serena Williams has won 17 matches || Venus Williams has won 8 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Venus Williams has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 68 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Venus Williams has won 5 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Venus Williams has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 28 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Nadia Petrova
#  INFO :  Serena Williams has won 7 matches || Nadia Petrova has won 3 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Nadia Petrova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 70 percent chance of winning the next match
#  INFO :  Martina Hingis has won 2 matches || Nadia Petrova has won 1 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Nadia Petrova has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 66 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Ana Ivanovic
#  INFO :  Serena Williams has won 9 matches || Ana Ivanovic has won 1 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Ana Ivanovic has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 90 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Ana Ivanovic has won 1 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Ana Ivanovic has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 50 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Sara Errani
#  INFO :  Serena Williams has won 9 matches || Sara Errani has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Sara Errani has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Sara Errani has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Sara Errani has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Francesca Schiavone
#  INFO :  Serena Williams has won 7 matches || Francesca Schiavone has won 2 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Francesca Schiavone has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 77 percent chance of winning the next match
#  INFO :  Martina Hingis has won 3 matches || Francesca Schiavone has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Francesca Schiavone has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Na Li
#  INFO :  Serena Williams has won 11 matches || Na Li has won 2 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Na Li has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 84 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Na Li has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Na Li has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match
#  INFO : ****************************************
#
#  INFO : Common Player is: Urszula Radwanska
#  INFO :  Serena Williams has won 5 matches || Urszula Radwanska has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Urszula Radwanska has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 0 matches || Urszula Radwanska has won 1 matches
#  INFO : ****************************************
#
#  INFO : Common Player is: Mirjana Lucic
#  INFO :  Serena Williams has won 1 matches || Mirjana Lucic has won 0 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Mirjana Lucic has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 100 percent chance of winning the next match
#  INFO :  Martina Hingis has won 1 matches || Mirjana Lucic has won 0 matches
#  INFO :  In last year, Martina Hingis has won 0 matches || Mirjana Lucic has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Martina Hingis has a 100 percent chance of winning the next match

# %%
player2 = "Martina Hingis"
player1 = "Serena Williams"
data = findNextWinner(matches, player1, player2)
logger.info("data >>> %s", data )
# Out:
#  INFO :  Serena Williams has won 4 matches || Martina Hingis has won 3 matches
#  INFO :  In last year, Serena Williams has won 0 matches || Martina Hingis has won 0 matches
#  INFO : Sorry, the two players haven't played in past one year.
#  INFO : Based on this information, Serena Williams has a 57 percent chance of winning the next match
#  INFO : data >>> ('Serena Williams', 57)

# %%
cols_of_interest = [ 'year', 'best_of', 'loser_age', 'winner_age', 
                    'draw_size',  'loser_name',
                    'loser_rank', 'winner_id', 'winner_name',
                    'winner_ioc','winner_rank','tourney_id', 
                    'tourney_name','tourney_date', 'score']

player1 = 'Serena Williams'
player2 = 'Maria Sharapova'
match_stats = matches[ ( (( matches['winner_name'] == player1) | 
           ( matches['loser_name'] == player1) ) &
          ( ( matches['loser_name'] == player2)  |
          ( matches['winner_name'] == player2) ))][cols_of_interest]

# %%
#One Player perspective
features =  ['date', '# of Matches Won', '# of Matches Lost', "year", 'Surface Type', 'age', 'Scores' ]

#
featuresToWeights = {
            "WinCounts" : 60,
            "LastYear" : 40,
            }

# %% [markdown]
# ### Data visualization

# %% [markdown]
# We will visualize some of the data - eg, who has won most of the grand slams, who is second etc

# %%
matches.head()
# Out:
#    best_of  draw_size  loser_age loser_entry loser_hand  loser_ht  loser_id  \
# 0        3        128         17         NaN          R       NaN    200002
# 1        3        128         27           Q          R       NaN    200004
# 2        3        128         31         NaN          R       NaN    200005
# 3        3        128         22         NaN          R       NaN    200007
# 4        3        128         24         NaN          R       NaN    200010
#
#   loser_ioc             loser_name loser_rank  ...  winner_hand winner_ht  \
# 0       CRO          Mirjana Lucic       49.0  ...            R     170.0
# 1       AUS        Kerry Anne Guse      133.0  ...            R     167.0
# 2       USA  Jolene Watanabe Giltz      118.0  ...            R       NaN
# 3       CRO         Silvija Talaja       23.0  ...            R     182.0
# 4       ITA            Rita Grande       60.0  ...            R     165.0
#
#    winner_id  winner_ioc          winner_name winner_rank winner_rank_points  \
# 0     200001         SUI       Martina Hingis         1.0             6003.0
# 1     200003         BEL        Justine Henin        63.0              510.0
# 2     200006         SVK     Karina Habsudova        53.0              574.0
# 3     200008         AUS         Alicia Molik       116.0              245.0
# 4     200009         THA  Tamarine Tanasugarn        72.0              439.0
#
#   winner_seed  year Unnamed: 32
# 0         1.0  2000         NaN
# 1         NaN  2000         NaN
# 2         NaN  2000         NaN
# 3         NaN  2000         NaN
# 4         NaN  2000         NaN
#
# [5 rows x 33 columns]

# %%
curr_year = datetime.datetime.today()
prev_year = datetime.datetime.today() - datetime.timedelta(days= 365)

prev_year.year
# Out:
# 2019
